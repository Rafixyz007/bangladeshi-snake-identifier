# %% [markdown]
# # 🐍 Bangladeshi Snake Recognizer
#
# | No. | English Name            | বাংলা নাম          | Type            |
# |-----|-------------------------|-------------------|-----------------|
# | 1   | Spectacled Cobra        | গোখরা             | Venomous        |
# | 2   | Monocled Cobra          | চশমা গোখরা        | Venomous        |
# | 3   | King Cobra              | রাজ গোখরা         | Venomous        |
# | 4   | Common Krait            | কালাই সাপ         | Venomous        |
# | 5   | Banded Krait            | ব্যান্ডেড ক্রাইট  | Venomous        |
# | 6   | Russell's Viper         | চন্দ্রবোড়া        | Venomous        |
# | 7   | Saw-scaled Viper        | একিস ভাইপার      | Venomous        |
# | 8   | Green Pit Viper         | সবুজ পিট ভাইপার   | Venomous        |
# | 9   | Beaked Sea Snake        | সমুদ্র সাপ        | Venomous        |
# | 10  | Yellow-lipped Sea Krait | সমুদ্র ক্রাইট     | Venomous        |
# | 11  | Indian Rock Python      | আজগর              | Non-Venomous    |
# | 12  | Rat Snake               | দাড়াশ             | Non-Venomous    |
# | 13  | Checkered Keelback      | ধামন              | Non-Venomous    |
# | 14  | Common Wolf Snake       | নেকড়ে সাপ         | Non-Venomous    |
# | 15  | Green Trinket Snake     | সবুজ সাপ          | Non-Venomous    |
# | 16  | Bronzeback Tree Snake   | গাছে ওঠা সাপ     | Non-Venomous    |
# | 17  | Common Kukri Snake      | কুক্রি সাপ        | Non-Venomous    |

# %% [markdown]
# # Setting Up for Inference model 01  (resnet34)

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Bangladeshi_snake_recognizer
# Out:
# /content/drive/My Drive/Bangladeshi_snake_recognizer

# %%
image_path = "test images"

# %%
model_01 = load_learner("/content/drive/MyDrive/Bangladeshi_snake_recognizer/bangladeshi-snake-recognizer-v1.pkl")
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %% [markdown]
# # Inference 1
#
# ###target:
# Yellow-lipped Sea Krait

# %%
img = Image.open(f'{image_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x114>

# %%
model_01.predict(f'{image_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Yellow-lipped_Sea_Krait',
#  tensor(16),
#  tensor([1.2227e-02, 9.2840e-04, 1.4480e-04, 1.2239e-05, 2.1216e-03, 1.1585e-04,
#          9.3010e-06, 3.1085e-05, 1.0732e-06, 6.3276e-06, 4.2911e-05, 3.4395e-06,
#          1.8868e-06, 3.7629e-07, 4.2458e-06, 3.4168e-06, 9.8435e-01]))

# %%
pred, pred_idx, probs = model_01.predict(f'{image_path}/unknown_00.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Yellow-lipped_Sea_Krait
# Confidence: 98.43%

# %% [markdown]
# #Inference 2
#
# ###target:
#
# monocled Cobra

# %%
img = Image.open(f'{image_path}/unknown_07.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x49>

# %%
model_01.predict(f'{image_path}/unknown_07.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('King_Cobra',
#  tensor(10),
#  tensor([1.3482e-04, 2.1088e-03, 1.1923e-03, 5.8236e-02, 1.4405e-04, 3.9184e-03,
#          3.1693e-03, 9.0802e-03, 7.9035e-04, 1.0765e-04, 4.6278e-01, 2.7627e-01,
#          7.0912e-03, 3.7189e-03, 5.0829e-04, 1.7054e-01, 2.1187e-04]))

# %%
pred, pred_idx, probs = model_01.predict(f'{image_path}/unknown_07.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: King_Cobra
# Confidence: 46.28%

# %% [markdown]
# #Inference 03
#
# ###target:
# Saw-scaled Viper

# %%
img = Image.open(f'{image_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model_01.predict(f'{image_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Saw-scaled_Viper',
#  tensor(14),
#  tensor([1.2277e-05, 3.9899e-06, 1.4651e-04, 2.3490e-06, 4.1274e-06, 7.3867e-06,
#          7.9418e-04, 1.4989e-05, 2.4757e-06, 3.3025e-04, 6.2022e-07, 6.3296e-07,
#          5.1356e-05, 9.7815e-04, 9.9764e-01, 1.8083e-06, 4.1589e-06]))

# %%
pred, pred_idx, probs = model_01.predict(f'{image_path}/unknown_02.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Saw-scaled_Viper
# Confidence: 99.76%

# %% [markdown]
# #Inference 04
#
# ###target:
# Russell's Viper

# %%
img = Image.open(f'{image_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model_01.predict(f'{image_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Russell's_Viper",
#  tensor(13),
#  tensor([9.5666e-07, 4.0783e-08, 9.0703e-06, 3.2964e-06, 6.3257e-07, 1.4536e-05,
#          3.4656e-06, 4.4296e-06, 9.7837e-07, 6.8434e-03, 3.6373e-07, 4.3496e-07,
#          2.6562e-05, 9.9303e-01, 5.7495e-05, 6.5883e-07, 3.1161e-08]))

# %%
pred, pred_idx, probs = model_01.predict(f'{image_path}/unknown_03.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Russell's_Viper
# Confidence: 99.30%

# %% [markdown]
# #Inference 05
#
# ###target:
# rat-snake

# %%
img = Image.open(f'{image_path}/unknown_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model_01.predict(f'{image_path}/unknown_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rat_Snake',
#  tensor(12),
#  tensor([3.6727e-03, 2.8139e-03, 8.9958e-03, 1.5800e-02, 4.3100e-03, 1.0346e-04,
#          2.6689e-03, 4.2198e-04, 5.1364e-02, 6.4899e-03, 1.5745e-02, 6.1256e-03,
#          8.2201e-01, 5.8629e-03, 1.0035e-02, 4.2257e-02, 1.3266e-03]))

# %%
pred, pred_idx, probs = model_01.predict(f'{image_path}/unknown_04.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Rat_Snake
# Confidence: 82.20%

# %% [markdown]
# # Setting Up for Inference model 02 (efficientnet_b0)

# %%
model_02 = load_learner("/content/drive/MyDrive/Bangladeshi_snake_recognizer/bangladeshi-snake-recognizer-v2.pkl")
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %% [markdown]
# # Inference 1
#
# ###target:
# Yellow-lipped Sea Krait

# %%
img = Image.open(f'{image_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x114>

# %%
model_02.predict(f'{image_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Yellow-lipped_Sea_Krait',
#  tensor(16),
#  tensor([1.9773e-03, 3.2670e-02, 1.6641e-05, 4.6199e-05, 1.9886e-04, 2.5029e-04,
#          7.2791e-06, 1.4267e-05, 6.0796e-06, 2.0707e-05, 7.3381e-05, 3.9459e-06,
#          8.5598e-06, 1.2403e-05, 4.3093e-06, 3.4562e-05, 9.6466e-01]))

# %%
pred, pred_idx, probs = model_02.predict(f'{image_path}/unknown_00.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Yellow-lipped_Sea_Krait
# Confidence: 96.47%

# %% [markdown]
# #Inference 2
#
# ###target
# monocled Cobra

# %%
img = Image.open(f'{image_path}/unknown_07.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x49>

# %%
model_02.predict(f'{image_path}/unknown_07.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Monocled_Cobra',
#  tensor(11),
#  tensor([8.3679e-06, 1.3146e-05, 4.2680e-06, 2.5541e-04, 7.7013e-06, 8.1432e-04,
#          2.2669e-05, 1.3800e-05, 1.5969e-05, 1.6997e-04, 2.2485e-02, 7.6207e-01,
#          1.3859e-04, 1.9033e-03, 4.8493e-05, 2.1203e-01, 2.1703e-06]))

# %%
pred, pred_idx, probs = model_02.predict(f'{image_path}/unknown_07.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Monocled_Cobra
# Confidence: 76.21%

# %% [markdown]
# #Inference 03
#
# ###target:
# Saw-scaled Viper

# %%
img = Image.open(f'{image_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model_02.predict(f'{image_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Saw-scaled_Viper',
#  tensor(14),
#  tensor([1.2785e-06, 5.3160e-07, 1.0691e-06, 1.4134e-07, 5.5122e-07, 8.7213e-06,
#          2.2591e-06, 2.9234e-06, 1.7818e-07, 9.8702e-06, 1.6026e-07, 2.3840e-08,
#          1.9516e-05, 6.5234e-04, 9.9930e-01, 1.1395e-07, 1.3240e-06]))

# %%
pred, pred_idx, probs = model_02.predict(f'{image_path}/unknown_02.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Saw-scaled_Viper
# Confidence: 99.93%

# %% [markdown]
# #Inference 04
#
# ###target:
# Russell's Viper

# %%
img = Image.open(f'{image_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model_02.predict(f'{image_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Russell's_Viper",
#  tensor(13),
#  tensor([1.2278e-05, 7.1147e-07, 3.2362e-05, 2.3078e-06, 2.4345e-06, 1.9612e-05,
#          3.9225e-06, 2.6747e-06, 1.3532e-05, 8.6326e-03, 1.6808e-05, 1.4804e-06,
#          2.9297e-04, 9.8882e-01, 2.1374e-03, 2.8166e-06, 2.3074e-06]))

# %%
pred, pred_idx, probs = model_02.predict(f'{image_path}/unknown_03.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Russell's_Viper
# Confidence: 98.88%

# %% [markdown]
# #Inference 05
#
# ###target:
# rat-snake

# %%
img = Image.open(f'{image_path}/unknown_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model_02.predict(f'{image_path}/unknown_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rat_Snake',
#  tensor(12),
#  tensor([0.0086, 0.3277, 0.0125, 0.0237, 0.0046, 0.0008, 0.0024, 0.0174, 0.0560,
#          0.0010, 0.0841, 0.0391, 0.3759, 0.0353, 0.0037, 0.0034, 0.0037]))

# %%
pred, pred_idx, probs = model_02.predict(f'{image_path}/unknown_04.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Rat_Snake
# Confidence: 37.59%

# %% [markdown]
# # Setting Up for Inference model 03 (resnet50)

# %%
model_03 = load_learner("/content/drive/MyDrive/Bangladeshi_snake_recognizer/bangladeshi-snake-recognizer-v3.pkl")
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %% [markdown]
# # Inference 1
#
# ###target:
# Yellow-lipped Sea Krait

# %%
img = Image.open(f'{image_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x114>

# %%
model_03.predict(f'{image_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Yellow-lipped_Sea_Krait',
#  tensor(16),
#  tensor([3.0887e-02, 1.6270e-02, 1.2398e-05, 8.5339e-06, 2.8871e-03, 5.9150e-05,
#          1.7806e-04, 1.4544e-05, 1.3119e-05, 1.3866e-05, 6.2059e-04, 3.5933e-05,
#          2.8964e-05, 2.1466e-05, 1.1901e-04, 2.6228e-04, 9.4857e-01]))

# %%
pred, pred_idx, probs = model_03.predict(f'{image_path}/unknown_00.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Yellow-lipped_Sea_Krait
# Confidence: 94.86%

# %% [markdown]
# #Inference 02
#
# ###target:
# monocled cobra

# %%
img = Image.open(f'{image_path}/unknown_07.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x49>

# %%
model_03.predict(f'{image_path}/unknown_07.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Monocled_Cobra',
#  tensor(11),
#  tensor([1.5966e-07, 8.4377e-07, 1.4361e-08, 2.7182e-05, 9.4002e-07, 1.0040e-05,
#          9.5695e-08, 2.0838e-08, 1.6084e-06, 5.0864e-09, 5.7172e-03, 9.9123e-01,
#          8.4898e-06, 7.1612e-04, 3.5528e-07, 2.2884e-03, 2.0404e-08]))

# %%
pred, pred_idx, probs = model_03.predict(f'{image_path}/unknown_07.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Monocled_Cobra
# Confidence: 99.12%

# %% [markdown]
# #Inference 03
#
# ###target:
# Saw-scaled Viper

# %%
img = Image.open(f'{image_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model_03.predict(f'{image_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Saw-scaled_Viper',
#  tensor(14),
#  tensor([4.4139e-09, 1.0502e-08, 3.6443e-09, 5.3684e-09, 4.7674e-09, 3.1092e-08,
#          6.2771e-08, 4.4645e-08, 1.1666e-06, 3.2233e-10, 3.6863e-10, 8.6813e-09,
#          4.2787e-08, 7.6561e-07, 1.0000e+00, 1.6549e-08, 1.8861e-08]))

# %%
pred, pred_idx, probs = model_03.predict(f'{image_path}/unknown_02.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Saw-scaled_Viper
# Confidence: 100.00%

# %% [markdown]
# #Inference 04
#
# ###target:
# Russell's Viper

# %%
img = Image.open(f'{image_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model_03.predict(f'{image_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("Russell's_Viper",
#  tensor(13),
#  tensor([8.4586e-07, 1.2141e-05, 1.1291e-04, 1.3540e-05, 5.6474e-07, 1.2149e-06,
#          1.9992e-05, 2.3242e-05, 8.6021e-06, 3.4278e-04, 8.7000e-06, 7.3418e-06,
#          9.1277e-07, 9.9801e-01, 1.4300e-03, 1.2360e-06, 1.1319e-06]))

# %%
pred, pred_idx, probs = model_03.predict(f'{image_path}/unknown_03.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Russell's_Viper
# Confidence: 99.80%

# %% [markdown]
# #Inference 05
#
# ###target:
# rat-snake

# %%
img = Image.open(f'{image_path}/unknown_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model_03.predict(f'{image_path}/unknown_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rat_Snake',
#  tensor(12),
#  tensor([2.4494e-03, 7.0083e-05, 1.1563e-05, 1.6761e-06, 1.4797e-03, 3.5777e-06,
#          1.9804e-06, 1.0233e-03, 3.7720e-03, 6.5823e-05, 2.6097e-02, 2.2246e-02,
#          9.4040e-01, 4.2786e-05, 4.8867e-05, 2.2438e-03, 3.7104e-05]))

# %%
pred, pred_idx, probs = model_03.predict(f'{image_path}/unknown_04.jpg')
print(f"Prediction: {pred}")
print(f"Confidence: {probs[pred_idx]:.2%}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: Rat_Snake
# Confidence: 94.04%
